# %%
from spacy import displacy
import spacy
from collections import Counter

import sys  
sys.path.insert(1, 'C:/Users/tom/projects/skill-skeleton/utils/')

import pdf_util as pdf_util


file_content = pdf_util.read_PDF('C:/Users/tom/projects/skill-skeleton/data/CV/20176584.pdf')

nlp=spacy.load('en_core_web_sm')
doc = nlp(file_content)
list_ent = [ent.label_ for ent in doc.ents]
labels, values = zip(*Counter(list_ent).items())

pdf_util.show_PDF_as_bar_chart(labels, values)


displacy.render(nlp(doc.text),style='ent', jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">CONSULTANT</br>Executive Profile</br>Accomplished high-energy Executive Manager with a strong background in manufacturing engineering and </br>over
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     25 years
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  of experience with</br>significant accomplishments in turnaround situations, team building, training, strategic planning,
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     P&amp;L
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ...
