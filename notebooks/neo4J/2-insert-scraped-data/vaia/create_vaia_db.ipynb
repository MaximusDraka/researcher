# %%
import time
import pandas as pd
from ast import literal_eval

import warnings
# Settings the warnings to be ignored 
warnings.filterwarnings('ignore') 

import sys
sys.path.insert(1, 'C:/Users/tom/projects/skill-skeleton/utils/')
sys.path.insert(2, 'C:/Users/tom/projects/skill-skeleton/utils/neo4j/')
from connection import Neo4jConnection
import query as query
import manage as manage
import kb_util


def add_skills(rows, batch_size=10000):
    # Adds skill nodes to the Neo4j graph as a batch job.  

    query = '''UNWIND $rows AS row   
    MERGE (s:Skill {name: row.skills})
    RETURN count(*) as total
    '''     
    
    return insert_data(query, rows, batch_size)


def fix_new_skills(rows, batch_size=10000):
    
    parameters = {'cat': "BD-ML-AI-Courses"}   
        
    query = '''UNWIND $rows AS row    
    MATCH (s:Skill {name: row.skills})
    WHERE s.category IS NULL
    SET s.category = $cat   
    RETURN count(*) as total
    '''      
    
    return insert_data(query, rows, batch_size, parameters)


def add_courses(rows, batch_size=10000):
    # Adds courses nodes to the Neo4j db as a batch job.    

    parameters = {'annotated_by': "manual"}   

    query = '''UNWIND $rows AS row
    MERGE (c:Course {title: row.title, url: row.url, date: row.date, course_info: row.course_info, start_time: row.start_time, language: row.language, location_detail: row.location_detail, target_group: row.target_group, subscription_limit: row.subscription_limit, constraints: row.constraints, price: row.price, details: row.details, sub_title: row.sub_title, intro: row.intro, full_body: row.full_body, data: row.data, annotated_by: $annotated_by})
    RETURN count(*) as total
    '''
    return insert_data(query, rows, batch_size, parameters)


def add_links(rows, batch_size=5000):
    # Adds profile nodes and (:Course)--(:Skill)
    # relationships to the Neo4j graph as a batch job.  (Note the smaller batch
    # size due to the fact that this function is adding much more data than the
    # add_skills() function.)

    query = '''
    UNWIND $rows as row   
    WITH row
    MATCH (s:Skill {name: row.skills})   
    MATCH (c:Course {url: row.url})
    MERGE (c)-[:OFFERS]->(s)
    RETURN count(distinct s) as total
    '''

    return insert_data(query, rows, batch_size)


def insert_data(query, rows, batch_size = 10000, parameters=None):
    # Function to handle the updating the Neo4j database in batch mode.

    total = 0
    batch = 0
    start = time.time()
    result = None

    while batch * batch_size < len(rows):

        if parameters is None:
            param = {'rows': rows[batch*batch_size:(batch+1)*batch_size].to_dict('records')}        
        else:
            param = parameters | {'rows': rows[batch*batch_size:(batch+1)*batch_size].to_dict('records')}

        print(param)
        
        res = conn.query(query, parameters=param)
        total += res[0]['total']
        batch += 1
        result = {"total":total, "batches":batch, "time":time.time()-start}
        print(result)

    return result


def get_skills(df):    
           
    df['skills'] = df['skills'].apply(kb_util.fix)
    
    return df[['url','skills']]


def get_courses(df):    
    
    df = df.fillna("NA")       
    return df.drop_duplicates()


def populate_db(df):
    
    df = df[df['skills']!="[]"] 
    df = df[df["language"]=="English"]    
      
     
    courses = get_courses(df)
    
    skills = get_skills(df)    
    skills['skills'] = skills['skills'].apply(literal_eval)    
    exploded_skills = skills.explode('skills').drop_duplicates().dropna()
            
    add_courses(courses)    
    add_skills(exploded_skills)
    add_links(exploded_skills)
    fix_new_skills(exploded_skills)
    
    
def configure_db():
    conn.query('CREATE CONSTRAINT courses IF NOT EXISTS FOR (c:Course) REQUIRE c.url IS UNIQUE')
    conn.query('CREATE TEXT INDEX course_text_index_url IF NOT EXISTS FOR (c:Course) ON (c.url)')
    conn.query('CREATE TEXT INDEX skill_text_index_name IF NOT EXISTS FOR (s:Skill) ON (s.name)')


def setup_db(file):
    df = pd.read_csv(file,delimiter='|',dtype={'url':str, 'title':str, 'skills':str, 'language':str})
    
    # Specify the columns to consider when looking for duplicates
    columns = ['title','url','date']

    # Find and drop duplicates, this is normally already done after downloading the data
    df = df.drop_duplicates(subset=columns)    
    
    configure_db()
    populate_db(df)


def delete_course_skill_link():
    conn.query('MATCH (c:Course)-[e:OFFERS]->(s:Skill) delete e')


def delete_courses():
    conn.query('MATCH (c:Course) DETACH DELETE c')
    
    
def delete_skills(category):    
    parameters = {'cat': category}    
    conn.query('MATCH (s:Skill) WHERE s.category = $cat DETACH DELETE s', parameters=parameters)


def get_all_courses():
    query_string = '''
    MATCH (c:Course) RETURN c.title as title, c.url as url, c.date as date, c.course_info as course_info, c.start_time as start_time, c.language as language, c.location_detail as location_detail, c.target_group as target_group, c.subscription_limit as subscription_limit, c.constraints as constraints, c.price as price, c.details as details, c.sub_title as sub_title, c.intro as intro, c.full_body as full_body
    '''
    
    return pd.DataFrame([dict(_) for _ in conn.query(query_string)])    


def get_all_courses_for_NER():
    query_string = '''
    MATCH (c:Course) RETURN c.url as url, c.title as title, c.course_info as course_info, c.full_body as full_body, c.details as details, c.sub_title as sub_title, c.intro as intro
    '''
    
    return pd.DataFrame([dict(_) for _ in conn.query(query_string)])    


def refresh_matcher_and_scores(conn):
    manage.refresh_all_profile_skill_scores(conn)
    
    skill_without_duplicates = query.get_all_skills(conn)
    kb_util.create_matcher_from_db('C:/Users/tom/projects/skill-skeleton/models/NER/finalized_matcher.sav',skill_without_duplicates, save=True)
  
   
conn = Neo4jConnection(uri="bolt://localhost:7687", 
                       user="neo4j",              
                       pwd="neo4jneo4j")

# %%
#delete_course_skill_link()
#delete_courses()
#delete_skills("BD-ML-AI-Courses")
setup_db("vaia-final-data-IT2.csv")
refresh_matcher_and_scores(conn)
# Out:
# {'annotated_by': 'manual', 'rows': [{'title': 'Gender and AI, a feminist perspective', 'url': 'https://www.vaia.be/en/courses/gender-and-ai-a-feminist-perspective', 'date': '22/03/2024', 'course_info': 'lecture-Brussels-FARI', 'start_time': '25 Mar 2024 17:30 - 19:00', 'language': 'English', 'location_detail': 'FARI  Cantersteen 16, 1000 Brussels', 'target_group': 'Target audience: Administrators, industry professionals and AI enthusiasts are invited to join this session.', 'subscription_limit': 'NA', 'constraints': 'NA', 'price': 'Gratis', 'details': 'https://www.vub.be/en/event/ai-happy-hour-gender-and-ai-feminist-perspective', 'sub_title': '25 Mar 2024 17:30 - 19:00', 'intro': 'More info  Share this course  ', 'full_body': ' For this session  Anastasia Karagianni  Doctoral Candidate at the LSTS Department of the Law and Criminology Faculty of VUB  will examine gender issues in AI from a feminist perspective. Through constant interaction with the audience  key definitions of AI will be provided (1st part)  examples/case studies of discriminatory treatment by AI systems will be referred (2nd part)  while an analysis of gender equality ethics and feminist principles will be shared to address these issues. A balanced mix of learning and relaxation Attendees will have the opportunity to delve into sustainable digitalisation with Anastasia  followed by a casual happy hour with snacks and beverages! This event is free to attend  but registration is compulsory. ', 'data': 'Gender and AI a feminist perspective  For this session  Anastasia Karagianni  Doctoral Candidate at the LSTS Department of the Law and Criminology Faculty of VUB  will examine gender issues in AI from a feminist perspective Through constant interaction with the audience  key definitions of AI will be provided 1st part  examplescase studies of discriminatory treatment by AI systems will be referred 2nd part  while an analysis of gender equality ethics and feminist principles will be shared to address these issues A balanced mix of learning and relaxation Attendees will have the opportunity to delve into sustainable digitalisation with Anastasia  followed by a casual happy hour with snacks and beverages This event is free to attend  but registration is compulsory  More info  Share this course   httpswwwvubbeeneventaihappyhourgenderandaifeministperspective 25 Mar 2024 1730  1900 lectureBrusselsFARI', 'skills': "['AI', 'AI', 'AI', 'AI', 'analysis']"}, {'title': 'Enabling the future of work', 'url': 'https://www.vaia.be/en/courses/enabling-the-future-of-work', 'date': '21/03/2024', 'course_info': '1-day course-Brussels-FARI', 'start_time': '22 Mar 2024 09:30 - 16:30', 'language': 'English', 'location_detail': 'Be Central, FARI Experience Centre - Cantersteen 16, 1000 Bruxelles', 'target_group': 'Target audience: decision makers from public organizations', 'subscription_limit': 'NA', 'constraints': 'have a clear challenge in mind when joining this session. Knowledge of legal frameworks or AI is not necessary.', 'price': '€250 excl. VAT', 'details': 'https://www.fari.brussels/education/enabling-the-future-of-work', 'sub_title': '22 Mar 2024 09:30 - 16:30', 'intro': 'More info  Share this course  ', 'full_body': " This course will be given by Prof. Rob Heyman on Friday 22 March 2024 from 9.30 to 16:30 CET at the FARI Test & Experience Center (Cantersteen 16  1000  Brussels). The problems or challenges we wish to address in this 1-day course are: Adopt AI or die: there is a push to use a form of artificial  intelligence for each organization  and failure to do so seems to imply  the end of your organization's history. But how do you ensure that your  investments in AI are sustainable and successfully adopted by your  colleagues and employees? While you are adapting to this new technological context  you will also have to deal with new regulations. How will you do this? Lastly  adopting technological and legal change is not something you  do on your own  so what are method ...
# {'total': 46, 'batches': 1, 'time': 0.123626708984375}
# {'rows': [{'url': 'https://www.vaia.be/en/courses/gender-and-ai-a-feminist-perspective', 'skills': 'ai'}, {'url': 'https://www.vaia.be/en/courses/gender-and-ai-a-feminist-perspective', 'skills': 'analysis'}, {'url': 'https://www.vaia.be/en/courses/enabling-the-future-of-work', 'skills': 'ai'}, {'url': 'https://www.vaia.be/en/courses/enabling-the-future-of-work', 'skills': 'automation'}, {'url': 'https://www.vaia.be/en/courses/enabling-the-future-of-work', 'skills': 'understand innovation'}, {'url': 'https://www.vaia.be/en/courses/enabling-the-future-of-work', 'skills': 'boosting operational efficiency'}, {'url': 'https://www.vaia.be/en/courses/enabling-the-future-of-work', 'skills': 'gdpr'}, {'url': 'https://www.vaia.be/en/courses/enabling-the-future-of-work', 'skills': 'workshop'}, {'url': 'https://www.vaia.be/en/courses/enabling-the-future-of-work', 'skills': 'facilitation methods'}, {'url': 'https://www.vaia.be/en/courses/enabling-the-future-of-work', 'skills': 'business needs'}, {'url': 'https://www.vaia.be/en/courses/a-new-symbolic-numeric-method-to-solve-the-multiparameter-eigenvalue-problem', 'skills': 'eigenvalue'}, {'url': 'https://www.vaia.be/en/courses/a-new-symbolic-numeric-method-to-solve-the-multiparameter-eigenvalue-problem', 'skills': 'polynomial systems'}, {'url': 'https://www.vaia.be/en/courses/a-new-symbolic-numeric-method-to-solve-the-multiparameter-eigenvalue-problem', 'skills': 'generalizations'}, {'url': 'https://www.vaia.be/en/courses/a-new-symbolic-numeric-method-to-solve-the-multiparameter-eigenvalue-problem', 'skills': 'weyman complexes'}, {'url': 'https://www.vaia.be/en/courses/a-new-symbolic-numeric-method-to-solve-the-multiparameter-eigenvalue-problem', 'skills': 'dixon matrices'}, {'url': 'https://www.vaia.be/en/courses/generative-ai-conversations', 'skills': 'large language models'}, {'url': 'https://www.vaia.be/en/courses/generative-ai-conversations', 'skills': 'ai'}, {'url': 'https://www.vaia.be/en/courses/generative-ai-conversations', 'skills': 'generative ai'}, {'url': 'https://www.vaia.be/en/courses/generative-ai-conversations', 'skills': 'exploration'}, {'url': 'https://www.vaia.be/en/courses/generative-ai-conversations', 'skills': 'data privacy'}, {'url': 'https://www.vaia.be/en/courses/learning-bytes-festival-2024', 'skills': 'digital transformation'}, {'url': 'https://www.vaia.be/en/courses/learning-bytes-festival-2024', 'skills': 'ai'}, {'url': 'https://www.vaia.be/en/courses/the-impact-of-ai-on-women-and-gender', 'skills': 'ai'}, {'url': 'https://www.vaia.be/en/courses/the-impact-of-ai-on-women-and-gender', 'skills': 'artificial intelligence'}, {'url': 'https://www.vaia.be/en/courses/the-impact-of-ai-on-women-and-gender', 'skills': 'training data'}, {'url': 'https://www.vaia.be/en/courses/get-ready-to-comply-with-the-new-regulations-on-data-artificial-intelligence', 'skills': 'regulations on data'}, {'url': 'https://www.vaia.be/en/courses/get-ready-to-comply-with-the-new-regulations-on-data-artificial-intelligence', 'skills': 'artificial intelligence'}, {'url': 'https://www.vaia.be/en/courses/get-ready-to-comply-with-the-new-regulations-on-data-artificial-intelligence', 'skills': 'exploration'}, {'url': 'https://www.vaia.be/en/courses/get-ready-to-comply-with-the-new-regulations-on-data-artificial-intelligence', 'skills': 'european regulations'}, {'url': 'https://www.vaia.be/en/courses/get-ready-to-comply-with-the-new-regulations-on-data-artificial-intelligence', 'skills': 'develop'}, {'url': 'https://www.vaia.be/en/courses/get-ready-to-comply-with-the-new-regulations-on-data-artificial-intelligence', 'skills': 'gdpr'}, {'url': 'https://www.vaia.be/en/courses/get-ready-to-comply-with-the-new-regulations-on-data-artificial-intelligence', 'skills': 'eu data law'}, {'url': 'https://www.vaia.be/en/courses/get-ready-to-comply-with-the-new-regulations-on-data-artificial-intelligence', 'skills': 'data protection'}, {'url': 'https://www.vaia.be/en/courses/get-ready-to-comply-with-the-new-regu ...
# {'total': 361, 'batches': 1, 'time': 0.05099964141845703}
# {'rows': [{'url': 'https://www.vaia.be/en/courses/gender-and-ai-a-feminist-perspective', 'skills': 'ai'}, {'url': 'https://www.vaia.be/en/courses/gender-and-ai-a-feminist-perspective', 'skills': 'analysis'}, {'url': 'https://www.vaia.be/en/courses/enabling-the-future-of-work', 'skills': 'ai'}, {'url': 'https://www.vaia.be/en/courses/enabling-the-future-of-work', 'skills': 'automation'}, {'url': 'https://www.vaia.be/en/courses/enabling-the-future-of-work', 'skills': 'understand innovation'}, {'url': 'https://www.vaia.be/en/courses/enabling-the-future-of-work', 'skills': 'boosting operational efficiency'}, {'url': 'https://www.vaia.be/en/courses/enabling-the-future-of-work', 'skills': 'gdpr'}, {'url': 'https://www.vaia.be/en/courses/enabling-the-future-of-work', 'skills': 'workshop'}, {'url': 'https://www.vaia.be/en/courses/enabling-the-future-of-work', 'skills': 'facilitation methods'}, {'url': 'https://www.vaia.be/en/courses/enabling-the-future-of-work', 'skills': 'business needs'}, {'url': 'https://www.vaia.be/en/courses/a-new-symbolic-numeric-method-to-solve-the-multiparameter-eigenvalue-problem', 'skills': 'eigenvalue'}, {'url': 'https://www.vaia.be/en/courses/a-new-symbolic-numeric-method-to-solve-the-multiparameter-eigenvalue-problem', 'skills': 'polynomial systems'}, {'url': 'https://www.vaia.be/en/courses/a-new-symbolic-numeric-method-to-solve-the-multiparameter-eigenvalue-problem', 'skills': 'generalizations'}, {'url': 'https://www.vaia.be/en/courses/a-new-symbolic-numeric-method-to-solve-the-multiparameter-eigenvalue-problem', 'skills': 'weyman complexes'}, {'url': 'https://www.vaia.be/en/courses/a-new-symbolic-numeric-method-to-solve-the-multiparameter-eigenvalue-problem', 'skills': 'dixon matrices'}, {'url': 'https://www.vaia.be/en/courses/generative-ai-conversations', 'skills': 'large language models'}, {'url': 'https://www.vaia.be/en/courses/generative-ai-conversations', 'skills': 'ai'}, {'url': 'https://www.vaia.be/en/courses/generative-ai-conversations', 'skills': 'generative ai'}, {'url': 'https://www.vaia.be/en/courses/generative-ai-conversations', 'skills': 'exploration'}, {'url': 'https://www.vaia.be/en/courses/generative-ai-conversations', 'skills': 'data privacy'}, {'url': 'https://www.vaia.be/en/courses/learning-bytes-festival-2024', 'skills': 'digital transformation'}, {'url': 'https://www.vaia.be/en/courses/learning-bytes-festival-2024', 'skills': 'ai'}, {'url': 'https://www.vaia.be/en/courses/the-impact-of-ai-on-women-and-gender', 'skills': 'ai'}, {'url': 'https://www.vaia.be/en/courses/the-impact-of-ai-on-women-and-gender', 'skills': 'artificial intelligence'}, {'url': 'https://www.vaia.be/en/courses/the-impact-of-ai-on-women-and-gender', 'skills': 'training data'}, {'url': 'https://www.vaia.be/en/courses/get-ready-to-comply-with-the-new-regulations-on-data-artificial-intelligence', 'skills': 'regulations on data'}, {'url': 'https://www.vaia.be/en/courses/get-ready-to-comply-with-the-new-regulations-on-data-artificial-intelligence', 'skills': 'artificial intelligence'}, {'url': 'https://www.vaia.be/en/courses/get-ready-to-comply-with-the-new-regulations-on-data-artificial-intelligence', 'skills': 'exploration'}, {'url': 'https://www.vaia.be/en/courses/get-ready-to-comply-with-the-new-regulations-on-data-artificial-intelligence', 'skills': 'european regulations'}, {'url': 'https://www.vaia.be/en/courses/get-ready-to-comply-with-the-new-regulations-on-data-artificial-intelligence', 'skills': 'develop'}, {'url': 'https://www.vaia.be/en/courses/get-ready-to-comply-with-the-new-regulations-on-data-artificial-intelligence', 'skills': 'gdpr'}, {'url': 'https://www.vaia.be/en/courses/get-ready-to-comply-with-the-new-regulations-on-data-artificial-intelligence', 'skills': 'eu data law'}, {'url': 'https://www.vaia.be/en/courses/get-ready-to-comply-with-the-new-regulations-on-data-artificial-intelligence', 'skills': 'data protection'}, {'url': 'https://www.vaia.be/en/courses/get-ready-to-comply-with-the-new-regu ...
# {'total': 228, 'batches': 1, 'time': 0.20399904251098633}
# {'cat': 'BD-ML-AI-Courses', 'rows': [{'url': 'https://www.vaia.be/en/courses/gender-and-ai-a-feminist-perspective', 'skills': 'ai'}, {'url': 'https://www.vaia.be/en/courses/gender-and-ai-a-feminist-perspective', 'skills': 'analysis'}, {'url': 'https://www.vaia.be/en/courses/enabling-the-future-of-work', 'skills': 'ai'}, {'url': 'https://www.vaia.be/en/courses/enabling-the-future-of-work', 'skills': 'automation'}, {'url': 'https://www.vaia.be/en/courses/enabling-the-future-of-work', 'skills': 'understand innovation'}, {'url': 'https://www.vaia.be/en/courses/enabling-the-future-of-work', 'skills': 'boosting operational efficiency'}, {'url': 'https://www.vaia.be/en/courses/enabling-the-future-of-work', 'skills': 'gdpr'}, {'url': 'https://www.vaia.be/en/courses/enabling-the-future-of-work', 'skills': 'workshop'}, {'url': 'https://www.vaia.be/en/courses/enabling-the-future-of-work', 'skills': 'facilitation methods'}, {'url': 'https://www.vaia.be/en/courses/enabling-the-future-of-work', 'skills': 'business needs'}, {'url': 'https://www.vaia.be/en/courses/a-new-symbolic-numeric-method-to-solve-the-multiparameter-eigenvalue-problem', 'skills': 'eigenvalue'}, {'url': 'https://www.vaia.be/en/courses/a-new-symbolic-numeric-method-to-solve-the-multiparameter-eigenvalue-problem', 'skills': 'polynomial systems'}, {'url': 'https://www.vaia.be/en/courses/a-new-symbolic-numeric-method-to-solve-the-multiparameter-eigenvalue-problem', 'skills': 'generalizations'}, {'url': 'https://www.vaia.be/en/courses/a-new-symbolic-numeric-method-to-solve-the-multiparameter-eigenvalue-problem', 'skills': 'weyman complexes'}, {'url': 'https://www.vaia.be/en/courses/a-new-symbolic-numeric-method-to-solve-the-multiparameter-eigenvalue-problem', 'skills': 'dixon matrices'}, {'url': 'https://www.vaia.be/en/courses/generative-ai-conversations', 'skills': 'large language models'}, {'url': 'https://www.vaia.be/en/courses/generative-ai-conversations', 'skills': 'ai'}, {'url': 'https://www.vaia.be/en/courses/generative-ai-conversations', 'skills': 'generative ai'}, {'url': 'https://www.vaia.be/en/courses/generative-ai-conversations', 'skills': 'exploration'}, {'url': 'https://www.vaia.be/en/courses/generative-ai-conversations', 'skills': 'data privacy'}, {'url': 'https://www.vaia.be/en/courses/learning-bytes-festival-2024', 'skills': 'digital transformation'}, {'url': 'https://www.vaia.be/en/courses/learning-bytes-festival-2024', 'skills': 'ai'}, {'url': 'https://www.vaia.be/en/courses/the-impact-of-ai-on-women-and-gender', 'skills': 'ai'}, {'url': 'https://www.vaia.be/en/courses/the-impact-of-ai-on-women-and-gender', 'skills': 'artificial intelligence'}, {'url': 'https://www.vaia.be/en/courses/the-impact-of-ai-on-women-and-gender', 'skills': 'training data'}, {'url': 'https://www.vaia.be/en/courses/get-ready-to-comply-with-the-new-regulations-on-data-artificial-intelligence', 'skills': 'regulations on data'}, {'url': 'https://www.vaia.be/en/courses/get-ready-to-comply-with-the-new-regulations-on-data-artificial-intelligence', 'skills': 'artificial intelligence'}, {'url': 'https://www.vaia.be/en/courses/get-ready-to-comply-with-the-new-regulations-on-data-artificial-intelligence', 'skills': 'exploration'}, {'url': 'https://www.vaia.be/en/courses/get-ready-to-comply-with-the-new-regulations-on-data-artificial-intelligence', 'skills': 'european regulations'}, {'url': 'https://www.vaia.be/en/courses/get-ready-to-comply-with-the-new-regulations-on-data-artificial-intelligence', 'skills': 'develop'}, {'url': 'https://www.vaia.be/en/courses/get-ready-to-comply-with-the-new-regulations-on-data-artificial-intelligence', 'skills': 'gdpr'}, {'url': 'https://www.vaia.be/en/courses/get-ready-to-comply-with-the-new-regulations-on-data-artificial-intelligence', 'skills': 'eu data law'}, {'url': 'https://www.vaia.be/en/courses/get-ready-to-comply-with-the-new-regulations-on-data-artificial-intelligence', 'skills': 'data protection'}, {'url': 'https://www.vaia.be/en/courses/get-ready- ...
# {'total': 109, 'batches': 1, 'time': 0.024000883102416992}
# Data Engineer
# Total objects for Data Engineer: 104
#                   skill        profile      score
# 520                 sql  Data Engineer  59.615385
# 562              python  Data Engineer  49.038462
# 511         programming  Data Engineer  42.307692
# 542                 aws  Data Engineer  39.423077
# 552                java  Data Engineer  37.500000
# ..                  ...            ...        ...
# 466               llama  Data Engineer   0.961538
# 464                 jde  Data Engineer   0.961538
# 463            bigtable  Data Engineer   0.961538
# 462           powerapps  Data Engineer   0.961538
# 346  database designing  Data Engineer   0.961538
#
# [693 rows x 3 columns]
# {'rows': [{'skill': 'azure', 'profile': 'Data Engineer', 'score': 22.115384615384613}, {'skill': 'project', 'profile': 'Data Engineer', 'score': 3.8461538461538463}, {'skill': 'vlookup', 'profile': 'Data Engineer', 'score': 0.9615384615384616}, {'skill': 'dashboard development', 'profile': 'Data Engineer', 'score': 0.9615384615384616}, {'skill': 'microsoft word', 'profile': 'Data Engineer', 'score': 0.9615384615384616}, {'skill': 'power query', 'profile': 'Data Engineer', 'score': 0.9615384615384616}, {'skill': 'statistical methods', 'profile': 'Data Engineer', 'score': 0.9615384615384616}, {'skill': 'ms powerpoint', 'profile': 'Data Engineer', 'score': 0.9615384615384616}, {'skill': 'gateway', 'profile': 'Data Engineer', 'score': 0.9615384615384616}, {'skill': 'functional requirements', 'profile': 'Data Engineer', 'score': 0.9615384615384616}, {'skill': 'validate data', 'profile': 'Data Engineer', 'score': 0.9615384615384616}, {'skill': 'r studio', 'profile': 'Data Engineer', 'score': 0.9615384615384616}, {'skill': 'ms word', 'profile': 'Data Engineer', 'score': 2.8846153846153846}, {'skill': 'test scripts', 'profile': 'Data Engineer', 'score': 0.9615384615384616}, {'skill': 'project planning', 'profile': 'Data Engineer', 'score': 0.9615384615384616}, {'skill': 'google sheets', 'profile': 'Data Engineer', 'score': 0.9615384615384616}, {'skill': 'process analysis', 'profile': 'Data Engineer', 'score': 1.9230769230769231}, {'skill': 'dml', 'profile': 'Data Engineer', 'score': 0.9615384615384616}, {'skill': 'microsoft access', 'profile': 'Data Engineer', 'score': 1.9230769230769231}, {'skill': 'text mining', 'profile': 'Data Engineer', 'score': 0.9615384615384616}, {'skill': 'business requirement', 'profile': 'Data Engineer', 'score': 1.9230769230769231}, {'skill': 'microsoft project', 'profile': 'Data Engineer', 'score': 1.9230769230769231}, {'skill': 'sass', 'profile': 'Data Engineer', 'score': 0.9615384615384616}, {'skill': 'data preparation', 'profile': 'Data Engineer', 'score': 0.9615384615384616}, {'skill': 'data cleaning', 'profile': 'Data Engineer', 'score': 0.9615384615384616}, {'skill': 'adobe photoshop', 'profile': 'Data Engineer', 'score': 0.9615384615384616}, {'skill': 'drupal', 'profile': 'Data Engineer', 'score': 0.9615384615384616}, {'skill': 'dashboard', 'profile': 'Data Engineer', 'score': 2.8846153846153846}, {'skill': 'crystal', 'profile': 'Data Engineer', 'score': 3.8461538461538463}, {'skill': 'data integrity', 'profile': 'Data Engineer', 'score': 3.8461538461538463}, {'skill': 'pivot tables', 'profile': 'Data Engineer', 'score': 1.9230769230769231}, {'skill': 'cryptography', 'profile': 'Data Engineer', 'score': 0.9615384615384616}, {'skill': 'business decisions', 'profile': 'Data Engineer', 'score': 0.9615384615384616}, {'skill': 'data sharing', 'profile': 'Data Engineer', 'score': 0.9615384615384616}, {'skill': 'risk assessment', 'profile': 'Data Engineer', 'score': 0.9615384615384616}, {'skill': 'tortoise svn', 'profile': 'Data Engineer', 'score': 0.9615384615384616}, {'skill': 'power point', 'profile': 'Data Engineer', 'score': 1.9230769230769231}, {'skill': 'dashboarding', 'profile': 'Data Engineer', 'score': 0.9615384615384616}, {'skill': 'stata', 'profile': 'Data Engineer', 'score': 0.9615384615384616}, {'skill': 'statistical techniques', 'profile': 'Data Engineer', 'score': 1.9230769230769231}, {'skill': 'statistical models', 'profile': 'Data Engineer', 'score': 0.9615384615384616}, {'skill': 'regularization', 'profile': 'Data Engineer', 'score': 0.9615384615384616}, {'skill': 'explanation', 'profile': 'Data Engineer', 'score': 0.9615384615384616}, {'skill': 'tomcat', 'profile': 'Data Engineer', 'score': 0.9615384615384616}, {'skill': 'pivot table', 'profile': 'Data Engineer', 'score': 0.9615384615384616}, {'skill': 'process redesign', 'profile': 'Data Engineer', 'score': 0.9615384615384616}, {'skill': 'ftp', 'profile': 'Data Engineer', 'score': 0.9615384615384616}, {'skill': 'cisco', 'profile': 'Da ...
# {'total': 693, 'batches': 1, 'time': 0.13300633430480957}
# Data Scientist
# Total objects for Data Scientist: 85
#                                skill         profile      score
# 502                           python  Data Scientist  68.235294
# 365                 machine learning  Data Scientist  50.588235
# 481                              sql  Data Scientist  45.882353
# 442                                r  Data Scientist  38.823529
# 408                    data analysis  Data Scientist  36.470588
# ..                               ...             ...        ...
# 236                         postgres  Data Scientist   1.176471
# 231                            spacy  Data Scientist   1.176471
# 58   artificial general intelligence  Data Scientist   1.176471
# 229                            react  Data Scientist   1.176471
# 54                  coding standards  Data Scientist   1.176471
#
# [538 rows x 3 columns]
# {'rows': [{'skill': 'decision tree', 'profile': 'Data Scientist', 'score': 3.5294117647058822}, {'skill': 'software products', 'profile': 'Data Scientist', 'score': 1.1764705882352942}, {'skill': 'uml', 'profile': 'Data Scientist', 'score': 1.1764705882352942}, {'skill': 'cobol', 'profile': 'Data Scientist', 'score': 1.1764705882352942}, {'skill': 'product requirements', 'profile': 'Data Scientist', 'score': 1.1764705882352942}, {'skill': 'version control', 'profile': 'Data Scientist', 'score': 1.1764705882352942}, {'skill': 'resource allocation', 'profile': 'Data Scientist', 'score': 2.3529411764705883}, {'skill': 'sensors', 'profile': 'Data Scientist', 'score': 1.1764705882352942}, {'skill': 'obiee', 'profile': 'Data Scientist', 'score': 1.1764705882352942}, {'skill': 'risk assessment and mitigation', 'profile': 'Data Scientist', 'score': 1.1764705882352942}, {'skill': 'cft', 'profile': 'Data Scientist', 'score': 1.1764705882352942}, {'skill': 'resource planning', 'profile': 'Data Scientist', 'score': 2.3529411764705883}, {'skill': 'supervised', 'profile': 'Data Scientist', 'score': 2.3529411764705883}, {'skill': 'regression testing', 'profile': 'Data Scientist', 'score': 2.3529411764705883}, {'skill': 'exchange', 'profile': 'Data Scientist', 'score': 2.3529411764705883}, {'skill': 'prototypes', 'profile': 'Data Scientist', 'score': 2.3529411764705883}, {'skill': 'visual studio', 'profile': 'Data Scientist', 'score': 2.3529411764705883}, {'skill': 'hipaa', 'profile': 'Data Scientist', 'score': 1.1764705882352942}, {'skill': 'tcl', 'profile': 'Data Scientist', 'score': 1.1764705882352942}, {'skill': 'consistent', 'profile': 'Data Scientist', 'score': 1.1764705882352942}, {'skill': 'project requirements', 'profile': 'Data Scientist', 'score': 1.1764705882352942}, {'skill': 'data warehouse', 'profile': 'Data Scientist', 'score': 1.1764705882352942}, {'skill': 'program management', 'profile': 'Data Scientist', 'score': 1.1764705882352942}, {'skill': 'db2', 'profile': 'Data Scientist', 'score': 1.1764705882352942}, {'skill': 'assembly', 'profile': 'Data Scientist', 'score': 1.1764705882352942}, {'skill': 'wireshark', 'profile': 'Data Scientist', 'score': 1.1764705882352942}, {'skill': 'tomcat', 'profile': 'Data Scientist', 'score': 1.1764705882352942}, {'skill': 'stl', 'profile': 'Data Scientist', 'score': 1.1764705882352942}, {'skill': 'web services', 'profile': 'Data Scientist', 'score': 1.1764705882352942}, {'skill': 'analytical thinking', 'profile': 'Data Scientist', 'score': 1.1764705882352942}, {'skill': 'cognos', 'profile': 'Data Scientist', 'score': 1.1764705882352942}, {'skill': 'ajax', 'profile': 'Data Scientist', 'score': 1.1764705882352942}, {'skill': 'web applications', 'profile': 'Data Scientist', 'score': 1.1764705882352942}, {'skill': 'user training', 'profile': 'Data Scientist', 'score': 1.1764705882352942}, {'skill': 'software testing', 'profile': 'Data Scientist', 'score': 1.1764705882352942}, {'skill': 'functional specifications', 'profile': 'Data Scientist', 'score': 1.1764705882352942}, {'skill': 'data integration', 'profile': 'Data Scientist', 'score': 1.1764705882352942}, {'skill': 'data integrity', 'profile': 'Data Scientist', 'score': 2.3529411764705883}, {'skill': 'technical expertise', 'profile': 'Data Scientist', 'score': 1.1764705882352942}, {'skill': 'plsql', 'profile': 'Data Scientist', 'score': 1.1764705882352942}, {'skill': 'project planning', 'profile': 'Data Scientist', 'score': 1.1764705882352942}, {'skill': 'experimental design', 'profile': 'Data Scientist', 'score': 2.3529411764705883}, {'skill': 'office', 'profile': 'Data Scientist', 'score': 2.3529411764705883}, {'skill': 'test scripts', 'profile': 'Data Scientist', 'score': 2.3529411764705883}, {'skill': 'watson', 'profile': 'Data Scientist', 'score': 1.1764705882352942}, {'skill': 'identify opportunities', 'profile': 'Data Scientist', 'score': 1.1764705882352942}, {'skill': 'loading', 'profile': 'Data Scientist', 'score': 1.1764705882352 ...
# {'total': 538, 'batches': 1, 'time': 0.03696560859680176}
# Data Analyst
# Total objects for Data Analyst: 111
#                   skill       profile      score
# 477               excel  Data Analyst  46.846847
# 515                 sql  Data Analyst  44.144144
# 358       data analysis  Data Analyst  39.639640
# 457            research  Data Analyst  28.828829
# 426  project management  Data Analyst  27.027027
# ..                  ...           ...        ...
# 270               cobol  Data Analyst   0.900901
# 84        data platform  Data Analyst   0.900901
# 266              pandas  Data Analyst   0.900901
# 85      troubleshooting  Data Analyst   0.900901
# 570  strategic thinking  Data Analyst   0.900901
#
# [571 rows x 3 columns]
# {'rows': [{'skill': 'data processing', 'profile': 'Data Analyst', 'score': 5.405405405405405}, {'skill': 'customer experience', 'profile': 'Data Analyst', 'score': 0.9009009009009009}, {'skill': 'text mining', 'profile': 'Data Analyst', 'score': 0.9009009009009009}, {'skill': 'tortoise svn', 'profile': 'Data Analyst', 'score': 0.9009009009009009}, {'skill': 'realtime data', 'profile': 'Data Analyst', 'score': 0.9009009009009009}, {'skill': 'tomcat', 'profile': 'Data Analyst', 'score': 0.9009009009009009}, {'skill': 'transforming', 'profile': 'Data Analyst', 'score': 0.9009009009009009}, {'skill': 'statistical models', 'profile': 'Data Analyst', 'score': 0.9009009009009009}, {'skill': 'dml', 'profile': 'Data Analyst', 'score': 0.9009009009009009}, {'skill': 'putty', 'profile': 'Data Analyst', 'score': 0.9009009009009009}, {'skill': 'trend analysis', 'profile': 'Data Analyst', 'score': 0.9009009009009009}, {'skill': 'regression', 'profile': 'Data Analyst', 'score': 1.8018018018018018}, {'skill': 'r studio', 'profile': 'Data Analyst', 'score': 0.9009009009009009}, {'skill': 'alteryx', 'profile': 'Data Analyst', 'score': 0.9009009009009009}, {'skill': 'cleansing', 'profile': 'Data Analyst', 'score': 0.9009009009009009}, {'skill': 'dimensional modeling', 'profile': 'Data Analyst', 'score': 0.9009009009009009}, {'skill': 'microsoft project', 'profile': 'Data Analyst', 'score': 1.8018018018018018}, {'skill': 'hdfs', 'profile': 'Data Analyst', 'score': 1.8018018018018018}, {'skill': 'maintaining', 'profile': 'Data Analyst', 'score': 0.9009009009009009}, {'skill': 'data sharing', 'profile': 'Data Analyst', 'score': 0.9009009009009009}, {'skill': 'sdlc', 'profile': 'Data Analyst', 'score': 1.8018018018018018}, {'skill': 'consistent', 'profile': 'Data Analyst', 'score': 0.9009009009009009}, {'skill': 'evaluation', 'profile': 'Data Analyst', 'score': 0.9009009009009009}, {'skill': 'reliability', 'profile': 'Data Analyst', 'score': 0.9009009009009009}, {'skill': 'regularization', 'profile': 'Data Analyst', 'score': 0.9009009009009009}, {'skill': 'eclipse', 'profile': 'Data Analyst', 'score': 0.9009009009009009}, {'skill': 'prototyping', 'profile': 'Data Analyst', 'score': 0.9009009009009009}, {'skill': 'software products', 'profile': 'Data Analyst', 'score': 0.9009009009009009}, {'skill': 'risk assessment', 'profile': 'Data Analyst', 'score': 1.8018018018018018}, {'skill': 'processing', 'profile': 'Data Analyst', 'score': 3.6036036036036037}, {'skill': 'consistency', 'profile': 'Data Analyst', 'score': 0.9009009009009009}, {'skill': 'cryptography', 'profile': 'Data Analyst', 'score': 0.9009009009009009}, {'skill': 'plsql', 'profile': 'Data Analyst', 'score': 1.8018018018018018}, {'skill': 'designing', 'profile': 'Data Analyst', 'score': 3.6036036036036037}, {'skill': 'loading', 'profile': 'Data Analyst', 'score': 2.7027027027027026}, {'skill': 'google sheets', 'profile': 'Data Analyst', 'score': 0.9009009009009009}, {'skill': 'detail oriented', 'profile': 'Data Analyst', 'score': 0.9009009009009009}, {'skill': 'teradata', 'profile': 'Data Analyst', 'score': 0.9009009009009009}, {'skill': 'hive', 'profile': 'Data Analyst', 'score': 0.9009009009009009}, {'skill': 'er studio', 'profile': 'Data Analyst', 'score': 0.9009009009009009}, {'skill': 'datasets', 'profile': 'Data Analyst', 'score': 2.7027027027027026}, {'skill': 'github', 'profile': 'Data Analyst', 'score': 0.9009009009009009}, {'skill': 'kibana', 'profile': 'Data Analyst', 'score': 0.9009009009009009}, {'skill': 'matlab', 'profile': 'Data Analyst', 'score': 0.9009009009009009}, {'skill': 'normalization', 'profile': 'Data Analyst', 'score': 0.9009009009009009}, {'skill': 'power point', 'profile': 'Data Analyst', 'score': 1.8018018018018018}, {'skill': 'adobe photoshop', 'profile': 'Data Analyst', 'score': 0.9009009009009009}, {'skill': 'reconciliation', 'profile': 'Data Analyst', 'score': 0.9009009009009009}, {'skill': 'onenote', 'profile': 'Data Analyst', 'score': 0.9009009009009009} ...
# {'total': 571, 'batches': 1, 'time': 0.0339655876159668}
# Business Analyst
# Total objects for Business Analyst: 0
# Software Engineer
# Total objects for Software Engineer: 0
# Machine Learning Engineer
# Total objects for Machine Learning Engineer: 0
# Cloud Engineer
# Total objects for Cloud Engineer: 0
