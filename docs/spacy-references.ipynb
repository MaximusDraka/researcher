# %% [markdown]
# Known NER TAGS
# -------------------------------------------------
#
# PERSON: for names of people ("John Doe")
#
# ORG: for organizations or companies ("XYZ Corp", "ABC University")
#
# GPE: for geopolitical entities like cities, states, countries
#
# DATE: for dates mentioned in the text ("5 years")
#
# SKILLS
#
# EDUCATION
#
# EXPERIENCE
#
# CERTIFICATIONS

# %% [markdown]
# Knowledge graph
# ------------------------------------
# https://walidamamou.medium.com/building-a-knowledge-graph-for-job-search-using-bert-transformer-8677c8b3a2e7
#
#
# Joint entities - SpaCy Relationship
# ------------------------------------
#
# https://towardsdatascience.com/how-to-train-a-joint-entities-and-relation-extraction-classifier-using-bert-transformer-with-spacy-49eb08d91b5c
# https://spacy.io/usage/layers-architectures#component-rel
# https://github.com/explosion/projects/tree/v3/tutorials/rel_component
#
#
# Spacy EN models
# ------------------------------------
# small model         = en_core_web_sm = efficiency
#
# medium model        = en_core_web_md
#
# large model         = en_core_web_lg
#
# transformer model   = en_core_web_trf = accuracy
#
# https://github.com/explosion/spacy-models/releases?q=en+NER&expanded=true
#
# Spacy NL Models
# ------------------------------------
# small model         = nl_news_web_sm = efficiency
#
# medium model        = nl_news_web_md
#
# large model         = nl_news_web_lg
#
#
# Download spacy model
# ------------------------------------
# python -m spacy download en_core_web_sm
#
#
# Load model
# -------------------------------------
# nlp_trf = spacy.load("en_core_web_trf")
#
#
# Prepare training data
# --------------------------------------
#
# https://spacy.io/usage/training#training-data
#
#
# Free Annotator
# --------------------------------------
# https://tecoholic.github.io/ner-annotator/
#
#
# Tokyo Tower is 333m tall.
#
# {"classes":["BUILDING"],"annotations":[["Tokyo Tower is 333m tall.",{"entities":[[0,11,"BUILDING"]]}]]}
#
#
#
# https://doccano.herokuapp.com/demo/named-entity-recognition
#
# https://morbo.ukp.informatik.tu-darmstadt.de/
#
#
# Paid Annotator
# -------------------------------------
#
# https://prodi.gy/
#
#
# Formats
# --------------------------------------
# https://github.com/dreji18/NER-Training-Spacy-3.0/blob/main/NER%20Training%20Data%20Annotation.ipynb
#
# https://spacy.io/api/data-formats
#
#
# Spacy Entity ruler
# --------------------------------------
#
# https://spacy.io/usage/rule-based-matching#entityruler
#
# from spacy.lang.en import English
#
# nlp = English()
# ruler = nlp.add_pipe("entity_ruler")
#
# patterns = [{"label": "ORG", "pattern": "Apple"},
#             {"label": "GPE", "pattern": [{"LOWER": "san"}, {"LOWER": "francisco"}]}]
#
# ruler.add_patterns(patterns)
# doc = nlp("Apple is opening its first big office in San Francisco.")
# print([(ent.text, ent.label_) for ent in doc.ents])
#
#
# BERT
# ---------------------------------------
#
# https://github.com/ghimiresunil/Fine-Tune-BERT-Transformer-with-Spacy-3-for-NER
#
# !pip install spacy-transformers
# !python -m spacy download en_trf_bertbaseuncased_lg
# import spacy
# import torch
#
# nlp = spacy.load("en_trf_bertbaseuncased_lg")
# doc = nlp("Here is some text to encode.")
# class Category:
#   BOOKS = "BOOKS"
#   BANK = "BANK"
#
# train_x = ["good characters and plot progression", "check out the book", "good story. would recommend", "novel recommendation", "need to make a deposit to the bank", "balance inquiry savings", "save money"]
# train_y = [Category.BOOKS, Category.BOOKS, Category.BOOKS, Category.BOOKS, Category.BANK, Category.BANK, Category.BANK]
# from sklearn import svm
#
# docs = [nlp(text) for text in train_x]
# train_x_vectors = [doc.vector for doc in docs]
# clf_svm = svm.SVC(kernel='linear')
#
# clf_svm.fit(train_x_vectors, train_y)
#
# test_x = ["check this story out"]
# docs = [nlp(text) for text in test_x]
# test_x_vectors = [doc.vector for doc in docs]
#
# clf_svm.predict(test_x_vectors)
#
#
#
# Train a pipeline configurator - CLI
# --------------------------------------
#
# https://spacy.io/usage/training
#
#
#
# pyresparser application
# ---------------------------------------
#
# Sample code for training a model
#
# https://omkarpathak.in/pyresparser/#explicitly_specifying_skills_file
#
# https://github.com/OmkarPathak/pyresparser/blob/master/pyresparser/ner/model
#
#
# Dataset
# ---------------------------------------
# https://github.com/DataTurks-Engg/Entity-Recognition-In-Resumes-SpaCy/blob/master/train.py
#
# Sample code to display the dataturk dataset
#
# https://www.kaggle.com/code/medelbachirkhellaf/resume-entities-for-ner/notebook
#
#
# Spacy pipelines and models
# ---------------------------------------
# https://github.com/explosion/projects
#
#
#
# Spacy linked entities video and tutorial code
# ---------------------------------------------
# https://github.com/explosion/projects/tree/v3/tutorials/nel_emerson
#
# https://www.youtube.com/watch?v=8u57WSXVpmw
#
#
#
# Training Custom NER
# ---------------------------------------------
#
# https://towardsdatascience.com/train-ner-with-custom-training-data-using-spacy-525ce748fab7
#
# https://github.com/Nishk23/spaCy-Custom-NER-creation/blob/master/NER%20solution.ipynb
#
#
#
# Examples
# ---------------------------------------
#
# Add entity manually to entities list + Vizualization of NER
#
# https://www.youtube.com/watch?v=PNbp3uoCgyI&list=PLZLuc8eJafeGhxG6I-1mTSItwAzlhgGV0&index=64
# https://colab.research.google.com/drive/1rFldRJ_08SmeKx4yeXOwqkfLZnTh1IW5?usp=sharing
#
#
# 𝐍𝐋𝐏 𝐏𝐫𝐨𝐣𝐞𝐜𝐭 (Part 3): Building A Name Entity Recognition Web App
#
# https://www.youtube.com/watch?v=gq5ncq4bKIQ&list=PLZLuc8eJafeGhxG6I-1mTSItwAzlhgGV0&index=65
#
#
# Job Tool
#
# https://github.com/ascheppach/job_resume_tool/blob/main/Named%20Entity%20Recognition.ipynb
#
#
# Automatic Skill Extraction from Resumes using spaCy
#
# https://medium.com/mlearning-ai/automatic-skill-extraction-from-resumes-using-spacy-710507624a1e
#
#
# Data extraction using NLP & spaCy in Resume Parsing
#
# https://github.com/rex2231/Resume_Parser
#
#
# NLP Tutorial 16 - CV and Resume Parsing with Custom NER Training with SpaCy
#
# https://www.youtube.com/watch?v=HJy11kOlgvk
#
#
# Resume (CV) Parsing using Spacy 3 | NER Training in Spacy v3
#
# https://www.youtube.com/watch?v=WpaioLNsoGI
#
#
# Use custom NER model in pipeline
#
# https://stackoverflow.com/questions/65751120/add-custom-ner-model-to-spacy-pipeline
#
# Train NER Spacy with dataturk annotator
#
# https://medium.com/analytics-vidhya/resume-parser-name-entity-recognization-using-spacy-86663d4683fa

# %%
import spacy

# Load the SpaCy English model
nlp = spacy.load("en_core_web_sm")

# Sample text (replace with your resume/job vacancy text)
text = "John Doe is skilled in Python and Java, with a Master's degree in Computer Science from ABC University. He worked at XYZ Corp as a Software Engineer for 5 years."

# Process the text with SpaCy
doc = nlp(text)

# Display NER entities and their labels
for ent in doc.ents:
    print(ent.text, "-", ent.label_)
# Out:
# John Doe - PERSON
# Python - GPE
# Java - PERSON
# Computer Science - ORG
# ABC University - ORG
# XYZ Corp - ORG
# 5 years - DATE
